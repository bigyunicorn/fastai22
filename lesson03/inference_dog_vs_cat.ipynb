# %% [markdown]
# <a href="https://colab.research.google.com/github/bigyunicorn/fastai22/blob/main/lesson03/inference_dog_vs_cat.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -Uqq fastai gradio

# %%
#|default_exp app

# %%
#|export
from fastai.vision.all import *
import gradio as gr

def is_cat(x): return x[0].isupper()

# %%
path = Path()
path.ls(file_exts='.pkl')
# Out:
# (#1) [Path('model.pkl')]

# %%
im = PILImage.create("dog.jpg")
im.thumbnail((192,192))
im
# Out:
# PILImage mode=RGB size=192x192

# %%
im2= PILImage.create('grizzlybear.jpg')
im2.thumbnail((192,192))
im2
# Out:
# PILImage mode=RGB size=192x143

# %%
#|export
learn = load_learner("model.pkl")

# %%
learn.dls.vocab
# Out:
# [False, True]

# %%
# %time learn.predict(im)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# CPU times: user 88.3 ms, sys: 4.99 ms, total: 93.3 ms
# Wall time: 96.9 ms
# ('False', tensor(0), tensor([9.9999e-01, 5.2741e-06]))

# %%
learn.predict(im)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('False', tensor(0), tensor([9.9999e-01, 5.2741e-06]))

# %%
learn.predict(PILImage.create("gift.jpg"))
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('True', tensor(1), tensor([0.0649, 0.9351]))

# %%
learn.predict(PILImage.create("box.jpg"))
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('True', tensor(1), tensor([0.0174, 0.9826]))

# %%
learn.predict(PILImage.create("grizzlybear.jpg"))
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('False', tensor(0), tensor([9.9993e-01, 6.6673e-05]))

# %%
learn.predict(PILImage.create("dog_and_cat3.png"))
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('True', tensor(1), tensor([0.4034, 0.5966]))

# %%
#|export
categories = ('Dog', 'Cat')

def classify_image(img):
  pred,idx,probs = learn.predict(img)
  return dict(zip(categories, map(float,probs))) # need to understand this line.

# %%
classify_image(im)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# {'Dog': 0.9999947547912598, 'Cat': 5.274098384688841e-06}

# %%
#|export
image = gr.inputs.Image(shape=(192,192))
label = gr.outputs.Label()
examples = ["cat.jpg", "dog.jpg", "grizzlybear.jpg", "box.jpg", "gift.jpg", "dog_and_cat.jpg", "dog_and_cat2.jpg", "dog_and_cat3.png"]

iface = gr.Interface(fn=classify_image, inputs=image, outputs=label, examples=examples)
iface.launch()
# Out:
# /usr/local/lib/python3.9/dist-packages/gradio/inputs.py:257: UserWarning: Usage of gradio.inputs is deprecated, and will not be supported in the future, please import your component from gradio.components
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/gradio/deprecation.py:40: UserWarning: `optional` parameter is deprecated, and it has no effect
#   warnings.warn(value)
# /usr/local/lib/python3.9/dist-packages/gradio/outputs.py:197: UserWarning: Usage of gradio.outputs is deprecated, and will not be supported in the future, please import your components from gradio.components
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/gradio/deprecation.py:40: UserWarning: The 'type' parameter has been deprecated. Use the Number component instead.
#   warnings.warn(value)
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# Note: opening Chrome Inspector may crash demo inside Colab notebooks.
#
# ...

# %%
# !pip install -U nbdev
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# %notebook -e yunnyTest.ipynb

# %%
from nbdev.export import nb_export
#from nbdev.export import notebook2script

# %%
nb_export('yunnyTest.ipynb', '.')

# %%
# !cat app.py
# Out:
# # AUTOGENERATED! DO NOT EDIT! File to edit: yunnyTest.ipynb.
#
# # %% auto 0
# __all__ = ['learn', 'categories', 'image', 'label', 'examples', 'iface', 'is_cat', 'classify_image']
#
# # %% yunnyTest.ipynb 2
# from fastai.vision.all import *
# import gradio as gr
#
# def is_cat(x): return x[0].isupper()
#
# # %% yunnyTest.ipynb 7
# learn = load_learner("model.pkl")
#
# # %% yunnyTest.ipynb 8
# learn = load_learner("model.pkl")
#
# # %% yunnyTest.ipynb 9
# learn = load_learner("model.pkl")
#
# # %% yunnyTest.ipynb 10
# learn = load_learner("model.pkl")
#
# # %% yunnyTest.ipynb 19
# categories = ('Dog', 'Cat')
#
# def classify_image(img):
#   pred,idx,probs = learn.predict(img)
#   return dict(zip(categories, map(float,probs))) # need to understand this line.
#
# # %% yunnyTest.ipynb 21
# image = gr.inputs.Image(shape=(192,192))
# label = gr.outputs.Label()
# ...

# %%
# !cat yunny.py
# Out:
# cat: yunny.py: No such file or directory
